# %%
# %pip install mlflow joblib
# Out:
# Requirement already satisfied: mlflow in ./.venv/lib/python3.11/site-packages (2.22.0)
# Requirement already satisfied: joblib in ./.venv/lib/python3.11/site-packages (1.4.2)
# Requirement already satisfied: mlflow-skinny==2.22.0 in ./.venv/lib/python3.11/site-packages (from mlflow) (2.22.0)
# Requirement already satisfied: Flask<4 in ./.venv/lib/python3.11/site-packages (from mlflow) (3.1.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in ./.venv/lib/python3.11/site-packages (from mlflow) (3.1.6)
# Requirement already satisfied: alembic!=1.10.0,<2 in ./.venv/lib/python3.11/site-packages (from mlflow) (1.15.2)
# Requirement already satisfied: docker<8,>=4.0.0 in ./.venv/lib/python3.11/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in ./.venv/lib/python3.11/site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: gunicorn<24 in ./.venv/lib/python3.11/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in ./.venv/lib/python3.11/site-packages (from mlflow) (3.8)
# Requirement already satisfied: matplotlib<4 in ./.venv/lib/python3.11/site-packages (from mlflow) (3.10.1)
# Requirement already satisfied: numpy<3 in ./.venv/lib/python3.11/site-packages (from mlflow) (2.2.5)
# Requirement already satisfied: pandas<3 in ./.venv/lib/python3.11/site-packages (from mlflow) (2.2.3)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in ./.venv/lib/python3.11/site-packages (from mlflow) (19.0.1)
# Requirement already satisfied: scikit-learn<2 in ./.venv/lib/python3.11/site-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in ./.venv/lib/python3.11/site-packages (from mlflow) (1.15.2)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in ./.venv/lib/python3.11/site-packages (from mlflow) (2.0.40)
# Requirement already satisfied: cachetools<6,>=5.0.0 in ./.venv/lib/python3.11/site-packages (from mlflow-skinny==2.22.0->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in ./.venv/lib/python3.11/site-packages (from mlflow-skinny==2.22.0->mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in ./.venv/lib/python3.11/site-packages (from mlflow-skinny==2.22.0->mlflow) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in ./.venv/lib/python3.11/site-packages (from mlflow-skinny==2.22.0->mlflow) (0.52.0)
# Requirement already satisfied: fastapi<1 in ./.venv/lib/python3.11/site-packages (from mlflow-skinny==2.22.0->mlflow) (0.115.12)
# Requirement already satisfied: gitpython<4,>=3.1.9 in ./.venv/lib/python3.11/site-packages (from mlflow-skinny==2.22.0->mlflow) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in ./.venv/lib/python3.11/site-packages (from mlflow-skinny==2.22.0->mlflow) (8.6.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in ./.venv/lib/python3.11/site-packages (from mlflow-skinny==2.22.0->mlflow) (1.32.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in ./.venv/lib/python3.11/site-packages (from mlflow-skinny==2.22.0->mlflow) (1.32.1)
# Requirement already satisfied: packaging<25 in ./.venv/lib/python3.11/site-packages (from mlflow-skinny==2.22.0->mlflow) (24.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in ./.venv/lib/python3.11/site-packages (from mlflow-skinny==2.22.0->mlflow) (6.30.2)
# Requirement already satisfied: pydantic<3,>=1.10.8 in ./.venv/lib/python3.11/site-packages (from mlflow-skinny==2.22.0->mlflow) (2.11.4)
# Requirement already satisfied: pyyaml<7,>=5.1 in ./.venv/lib/python3.11/site-packages (from mlflow-skinny==2.22.0->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in ./.venv/lib/python3.11/site-packages (from mlflow-skinny==2.22.0->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in ./.venv/lib/python3.11/site-packages (from mlflow-skinny==2.22.0->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in ./.venv/lib/python3.11/site-packages (from mlflow-skinny==2.22.0->mlflow) (4.13.2)
# Requirement already satisfied: uvicorn<1 in ./.venv/lib/python3.11/site-packages (from mlflow-skinny==2.22.0->mlflow) (0.34.2)
# Requirement already satisfied: Mako in ./.venv/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: urllib3>=1.26.0 in ./.venv/lib/python3.11/site-packages (from docker<8,>=4.0.0->mlflow) (2.4.0)
# Requirement already satisfied: Werkzeug>=3.1 in ./.venv/lib/python3.11/site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in ./.venv/lib/python3.11/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in ./.venv/lib/python3.11/site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in ./.venv/lib/python3.11/site-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in ./.venv/lib/python3.11/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in ./.venv/lib/python3.11/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.11/site-packages (from Jinja2<4,>=2.11->mlflow) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.11/site-packages (from matplotlib<4->mlflow) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.11/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.11/site-packages (from matplotlib<4->mlflow) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.11/site-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.11/site-packages (from matplotlib<4->mlflow) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.11/site-packages (from matplotlib<4->mlflow) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.11/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.11/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.11/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: google-auth~=2.0 in ./.venv/lib/python3.11/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (2.39.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in ./.venv/lib/python3.11/site-packages (from fastapi<1->mlflow-skinny==2.22.0->mlflow) (0.46.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.11/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.22.0->mlflow) (3.21.0)
# Requirement already satisfied: deprecated>=1.2.6 in ./.venv/lib/python3.11/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.53b1 in ./.venv/lib/python3.11/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (0.53b1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in ./.venv/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow) (0.4.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (2025.4.26)
# Requirement already satisfied: h11>=0.8 in ./.venv/lib/python3.11/site-packages (from uvicorn<1->mlflow-skinny==2.22.0->mlflow) (0.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in ./.venv/lib/python3.11/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (1.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (4.9.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in ./.venv/lib/python3.11/site-packages (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.11/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in ./.venv/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (0.6.1)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import os
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import mlflow
import mlflow.pytorch
from joblib import Parallel, delayed

# Configurar MLflow
mlflow.set_tracking_uri("http://localhost:5001")
mlflow.set_experiment("Prometheus_Transformer_Experiment_MRFO_NoRepetitions_Parallel")

# Definindo constantes
DATA_DIR = "../../data/"
FILE_PATH = os.path.join(DATA_DIR, 'ts.pkl')
SEQ_LENGTH = 48  # 12 horas (48 * 15min)
MB = 1_048_576

# 1. Carregar e reamostrar os dados para 15 minutos
df = pd.read_pickle(FILE_PATH)
ts = df['value'].astype(float).resample('15min').mean().dropna()
dates = ts.index

# 2. Dividir os dados: 60% treino, 20% validação, 20% teste
train_size = int(0.6 * len(ts))
val_size = int(0.2 * len(ts))
train = ts[:train_size]
val = ts[train_size:train_size + val_size]
test = ts[train_size + val_size:]

# 3. Escalonar os dados
scaler = StandardScaler()
train_scaled = scaler.fit_transform(train.values.reshape(-1, 1))
val_scaled = scaler.transform(val.values.reshape(-1, 1))
test_scaled = scaler.transform(test.values.reshape(-1, 1))

# 4. Criar sequências
def create_sequences(data, dates, seq_length):
    X, y, y_dates = [], [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length])
        y_dates.append(dates[i + seq_length])
    return np.array(X), np.array(y), np.array(y_dates)

X_train, y_train, y_dates_train = create_sequences(train_scaled, dates[:train_size], SEQ_LENGTH)
X_val, y_val, y_dates_val = create_sequences(val_scaled, dates[train_size:train_size + val_size], SEQ_LENGTH)
X_test, y_test, y_dates_test = create_sequences(test_scaled, dates[train_size + val_size:], SEQ_LENGTH)

# 5. Ajustar dimensões para o modelo Transformer
d_model = 128
X_train = np.repeat(X_train, d_model, axis=2)
X_val = np.repeat(X_val, d_model, axis=2)
X_test = np.repeat(X_test, d_model, axis=2)

# 6. Converter para tensores PyTorch
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# 7. Definir codificação posicional
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-np.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:, :x.size(1), :]
        return x

# 8. Definir o modelo Transformer (sem dropout adicional)
class Encoder(nn.Module):
    def __init__(self, input_dim, d_model, nhead, num_layers, dim_feedforward):
        super(Encoder, self).__init__()
        self.pos_encoder = PositionalEncoding(d_model)
        self.encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model, nhead=nhead, dim_feedforward=dim_feedforward, batch_first=True
        )
        self.transformer_encoder = nn.TransformerEncoder(self.encoder_layer, num_layers=num_layers)
        self.linear_out = nn.Linear(d_model, 1, bias=True)

    def forward(self, src):
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src)
        output = self.linear_out(output[:, -1, :])
        return output

# Outros hiperparâmetros fixos
input_dim = d_model
batch_size = 32
num_epochs = 50

# Função para calcular SMAPE
def smape(y_true, y_pred):
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2
    diff = np.abs(y_true - y_pred) / denominator
    return 100 * np.mean(diff)

# Função de treinamento e avaliação para uma única execução
def train_and_evaluate(learning_rate, num_layers, nhead, dim_feedforward):
    model = Encoder(input_dim, d_model, nhead, num_layers, dim_feedforward)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)

    best_val_loss = float('inf')
    patience = 5
    patience_counter = 0

    for epoch in range(num_epochs):
        model.train()
        for i in range(0, len(X_train), batch_size):
            X_batch = X_train[i:i + batch_size]
            y_batch = y_train[i:i + batch_size]
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            y_val_pred = model(X_val)
            val_loss = criterion(y_val_pred, y_val)
        
        scheduler.step(val_loss)
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                break

    model.eval()
    with torch.no_grad():
        y_pred = model(X_test)
    
    y_pred_rescaled = scaler.inverse_transform(y_pred.numpy()) / MB
    y_test_rescaled = scaler.inverse_transform(y_test.numpy()) / MB
    
    mae = mean_absolute_error(y_test_rescaled, y_pred_rescaled)
    rmse = np.sqrt(mean_squared_error(y_test_rescaled, y_pred_rescaled))
    mape = mean_absolute_percentage_error(y_test_rescaled, y_pred_rescaled) * 100
    smape_val = smape(y_test_rescaled, y_pred_rescaled)
    
    return mae, rmse, mape, smape_val, model

# Função de avaliação para uma manta (usada no MRFO)
def evaluate_manta(params):
    lr = 10 ** params[0]  # learning_rate (log scale)
    nl = map_continuous_to_discrete(params[1], [2, 3])  # num_layers
    nh = map_continuous_to_discrete(params[2], [4, 8])  # nhead
    df = map_continuous_to_discrete(params[3], [256, 512])  # dim_feedforward

    mae, _, _, _, _ = train_and_evaluate(lr, nl, nh, df)
    return mae

# Função de mapeamento de valores contínuos para discretos
def map_continuous_to_discrete(value, discrete_values):
    idx = int(round(value * (len(discrete_values) - 1)))
    idx = max(0, min(idx, len(discrete_values) - 1))
    return discrete_values[idx]

# Implementação do MRFO com saídas intermediárias e paralelismo
class MRFO:
    def __init__(self, objective_func, bounds, n_mantas=30, max_iter=100):
        self.objective_func = objective_func
        self.bounds = np.array(bounds).T  # Shape: (2, dim)
        self.n_mantas = n_mantas
        self.max_iter = max_iter
        self.dim = self.bounds.shape[1]
        
        # Inicializar população
        self.positions = np.zeros((self.n_mantas, self.dim))
        for d in range(self.dim):
            self.positions[:, d] = np.random.uniform(self.bounds[0, d], self.bounds[1, d], self.n_mantas)
        self.fitness = np.array([float('inf')] * self.n_mantas)
        self.best_position = None
        self.best_fitness = float('inf')

    def optimize(self):
        for t in range(self.max_iter):
            print(f"\nIteration {t+1}/{self.max_iter}")
            # Avaliar fitness de todas as mantas em paralelo
            fitness_results = Parallel(n_jobs=-1)(
                delayed(self.objective_func)(self.positions[i]) for i in range(self.n_mantas)
            )
            self.fitness = np.array(fitness_results)

            # Exibir resultados e atualizar o melhor fitness
            for i in range(self.n_mantas):
                print(f"  Manta {i+1}/{self.n_mantas}: Fitness (MAE) = {self.fitness[i]:.4f}")
                if self.fitness[i] < self.best_fitness:
                    self.best_fitness = self.fitness[i]
                    self.best_position = self.positions[i].copy()
                    print(f"  New Best Fitness: {self.best_fitness:.4f}")

            # Registrar melhor fitness no MLflow
            with mlflow.start_run(run_name=f"MRFO_Iteration_{t+1}"):
                mlflow.log_metric("best_fitness_mae", self.best_fitness)
                # Registrar os hiperparâmetros correspondentes ao melhor fitness
                lr = 10 ** self.best_position[0]
                nl = map_continuous_to_discrete(self.best_position[1], [2, 3])
                nh = map_continuous_to_discrete(self.best_position[2], [4, 8])
                df = map_continuous_to_discrete(self.best_position[3], [256, 512])
                mlflow.log_param("learning_rate", lr)
                mlflow.log_param("num_layers", nl)
                mlflow.log_param("nhead", nh)
                mlflow.log_param("dim_feedforward", df)

            # Atualizar posições usando Chain Foraging, Cyclone Foraging e Somersault Foraging
            for i in range(self.n_mantas):
                r = np.random.random(self.dim)
                r1 = np.random.random()

                # Chain Foraging
                if r1 < 0.5:
                    if i == 0:
                        self.positions[i] = self.positions[i] + r * (self.best_position - self.positions[i]) + \
                                            r * (self.best_position - self.positions[i])
                    else:
                        self.positions[i] = self.positions[i] + r * (self.positions[i-1] - self.positions[i]) + \
                                            r * (self.best_position - self.positions[i])

                # Cyclone Foraging
                else:
                    beta = 2 * np.exp(r1 * (self.max_iter - t + 1) / self.max_iter) * np.sin(2 * np.pi * r1)
                    if r1 < 0.5:
                        self.positions[i] = self.positions[i] + r * (self.best_position - beta * self.positions[i])
                    else:
                        idx = np.random.randint(0, self.n_mantas)
                        self.positions[i] = self.positions[i] + r * (self.positions[idx] - beta * self.positions[i])

                # Somersault Foraging
                r2 = np.random.random()
                self.positions[i] = self.positions[i] + 0.5 * (self.best_position + self.positions[i]) * (2 * r2 - 1)

                # Garantir que as posições estejam dentro dos limites
                self.positions[i] = np.clip(self.positions[i], self.bounds[0], self.bounds[1])

        return self.best_position, self.best_fitness

# MRFO para otimizar hiperparâmetros
bounds = [
    [-3.1, -2.9],  # log10(learning_rate): [0.0008, 0.0012]
    [0, 1],        # num_layers (mapeado para [2, 3])
    [0, 1],        # nhead (mapeado para [4, 8])
    [0, 1],        # dim_feedforward (mapeado para [256, 512])
]

mrfo = MRFO(evaluate_manta, bounds, n_mantas=50, max_iter=20)
best_position, best_fitness = mrfo.optimize()

# Mapear a melhor posição para hiperparâmetros
best_lr = 10 ** best_position[0]
best_nl = map_continuous_to_discrete(best_position[1], [2, 3])
best_nh = map_continuous_to_discrete(best_position[2], [4, 8])
best_df = map_continuous_to_discrete(best_position[3], [256, 512])

# Treinar o modelo com a melhor configuração para obter métricas finais (sem repetições)
with mlflow.start_run(run_name="Best_MRFO_Run"):
    # Registrar hiperparâmetros
    mlflow.log_param("learning_rate", best_lr)
    mlflow.log_param("num_layers", best_nl)
    mlflow.log_param("nhead", best_nh)
    mlflow.log_param("dim_feedforward", best_df)
    mlflow.log_param("seq_length", SEQ_LENGTH)
    mlflow.log_param("resample_interval", "15min")
    mlflow.log_param("batch_size", batch_size)
    mlflow.log_param("num_epochs", num_epochs)

    print(f"\nBest MRFO Configuration: LR={best_lr}, Layers={best_nl}, Heads={best_nh}, FF={best_df}")
    
    # Executar uma única vez (sem repetições)
    mae, rmse, mape, smape_val, best_model = train_and_evaluate(best_lr, best_nl, best_nh, best_df)

    print(f"  MAE: {mae}, RMSE: {rmse}, MAPE: {mape}%, SMAPE: {smape_val}%")

    # Registrar métricas no MLflow
    mlflow.log_metric("mae", mae)
    mlflow.log_metric("rmse", rmse)
    mlflow.log_metric("mape", mape)
    mlflow.log_metric("smape", smape_val)

    mlflow.pytorch.log_model(best_model, "best_model")

# 9. Fazer previsões
model = best_model
model.eval()
with torch.no_grad():
    y_train_pred = model(X_train)
    y_test_pred = model(X_test)

# 10. Reverter o escalonamento e converter para MB
y_train_pred_mb = scaler.inverse_transform(y_train_pred.numpy()) / MB
y_train_mb = scaler.inverse_transform(y_train.numpy()) / MB
y_test_pred_mb = scaler.inverse_transform(y_test_pred.numpy()) / MB
y_test_mb = scaler.inverse_transform(y_test.numpy()) / MB

# 11. Preparar dados para plotagem
train_df = pd.DataFrame({
    'date': y_dates_train,
    'actual': y_train_mb.flatten(),
    'predicted': y_train_pred_mb.flatten()
}).sort_values('date')

test_df = pd.DataFrame({
    'date': y_dates_test,
    'actual': y_test_mb.flatten(),
    'predicted': y_test_pred_mb.flatten()
}).sort_values('date')

# 12. Plotar os resultados
plt.style.use('default')
fig, axs = plt.subplots(2, 1, figsize=(15, 10), sharex=False)

axs[0].plot(train_df['date'], train_df['actual'], label='Real', color='blue', linewidth=1.5)
axs[0].plot(train_df['date'], train_df['predicted'], label='Predito', color='red', alpha=0.7, linewidth=1.5)
axs[0].set_title('Conjunto de Treinamento (60%)', fontsize=12, pad=10)
axs[0].set_ylabel('Consumo de Memória (MB)', fontsize=10)
axs[0].legend(loc='upper left', fontsize=10)
axs[0].grid(True, linestyle='--', alpha=0.7)

axs[1].plot(test_df['date'], test_df['actual'], label='Real', color='blue', linewidth=1.5)
axs[1].plot(test_df['date'], test_df['predicted'], label='Predito', color='red', alpha=0.7, linewidth=1.5)
axs[1].set_title('Conjunto de Teste (20%)', fontsize=12, pad=10)
axs[1].set_xlabel('Data', fontsize=10)
axs[1].set_ylabel('Consumo de Memória (MB)', fontsize=10)
axs[1].legend(loc='upper left', fontsize=10)
axs[1].grid(True, linestyle='--', alpha=0.7)

for ax in axs:
    ax.xaxis.set_major_locator(mdates.AutoDateLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    ax.tick_params(axis='x', rotation=45, labelsize=9)
    ax.tick_params(axis='y', labelsize=9)

plt.suptitle('Predições do Transformer Otimizado - Prometheus (MB, Resample 15min)', fontsize=14, y=0.98)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig(os.path.join(DATA_DIR, 'prometheus_transformer_mrfo_15min.png'), dpi=300, bbox_inches='tight')
plt.close()
# Out:
# Iteration 1/20
#   Manta 1/50: Fitness (MAE) = 34.1309
#   New Best Fitness: 34.1309
#   Manta 2/50: Fitness (MAE) = 10.5274
#   New Best Fitness: 10.5274
#   Manta 3/50: Fitness (MAE) = 30.3729
#   Manta 4/50: Fitness (MAE) = 18.6890
#   Manta 5/50: Fitness (MAE) = 9.1242
#   New Best Fitness: 9.1242
#   Manta 6/50: Fitness (MAE) = 14.4678
#   Manta 7/50: Fitness (MAE) = 30.6590
#   Manta 8/50: Fitness (MAE) = 6.6978
#   New Best Fitness: 6.6978
#   Manta 9/50: Fitness (MAE) = 13.2589
#   Manta 10/50: Fitness (MAE) = 13.2611
#   Manta 11/50: Fitness (MAE) = 11.0511
#   Manta 12/50: Fitness (MAE) = 12.3115
#   Manta 13/50: Fitness (MAE) = 11.1156
#   Manta 14/50: Fitness (MAE) = 10.2394
#   Manta 15/50: Fitness (MAE) = 20.0233
#   Manta 16/50: Fitness (MAE) = 10.3565
#   Manta 17/50: Fitness (MAE) = 18.8125
#   Manta 18/50: Fitness (MAE) = 10.5904
#   Manta 19/50: Fitness (MAE) = 11.8463
#   Manta 20/50: Fitness (MAE) = 18.2751
#   Manta 21/50: Fitness (MAE) = 7.0372
#   Manta 22/50: Fitness (MAE) = 17.1701
#   Manta 23/50: Fitness (MAE) = 17.8425
#   Manta 24/50: Fitness (MAE) = 21.5437
#   Manta 25/50: Fitness (MAE) = 7.9792
#   Manta 26/50: Fitness (MAE) = 17.1017
#   Manta 27/50: Fitness (MAE) = 24.7472
#   Manta 28/50: Fitness (MAE) = 22.2891
#   Manta 29/50: Fitness (MAE) = 27.4006
#   Manta 30/50: Fitness (MAE) = 8.3629
#   Manta 31/50: Fitness (MAE) = 7.5014
#   Manta 32/50: Fitness (MAE) = 20.5810
#   Manta 33/50: Fitness (MAE) = 15.7778
#   Manta 34/50: Fitness (MAE) = 7.1236
#   Manta 35/50: Fitness (MAE) = 15.8241
#   Manta 36/50: Fitness (MAE) = 21.8054
#   Manta 37/50: Fitness (MAE) = 5.7664
#   New Best Fitness: 5.7664
#   Manta 38/50: Fitness (MAE) = 17.5942
#   Manta 39/50: Fitness (MAE) = 29.9682
#   Manta 40/50: Fitness (MAE) = 6.8050
#   Manta 41/50: Fitness (MAE) = 10.5762
#   Manta 42/50: Fitness (MAE) = 11.7252
#   Manta 43/50: Fitness (MAE) = 7.0798
#   Manta 44/50: Fitness (MAE) = 16.5646
#   Manta 45/50: Fitness (MAE) = 9.1937
#   Manta 46/50: Fitness (MAE) = 31.7850
#   Manta 47/50: Fitness (MAE) = 16.0706
#   Manta 48/50: Fitness (MAE) = 8.7971
#   Manta 49/50: Fitness (MAE) = 25.2078
#   Manta 50/50: Fitness (MAE) = 13.6456
# 🏃 View run MRFO_Iteration_1 at: http://localhost:5001/#/experiments/6/runs/30e034bf4e914945956e05516588143e
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
#
# Iteration 2/20
#   Manta 1/50: Fitness (MAE) = 16.3124
#   Manta 2/50: Fitness (MAE) = 21.5590
#   Manta 3/50: Fitness (MAE) = 12.1389
#   Manta 4/50: Fitness (MAE) = 19.0739
#   Manta 5/50: Fitness (MAE) = 7.3999
#   Manta 6/50: Fitness (MAE) = 16.0302
#   Manta 7/50: Fitness (MAE) = 30.9446
#   Manta 8/50: Fitness (MAE) = 14.4766
#   Manta 9/50: Fitness (MAE) = 7.4321
#   Manta 10/50: Fitness (MAE) = 25.6934
#   Manta 11/50: Fitness (MAE) = 9.9406
#   Manta 12/50: Fitness (MAE) = 31.8630
#   Manta 13/50: Fitness (MAE) = 16.4837
#   Manta 14/50: Fitness (MAE) = 7.2795
#   Manta 15/50: Fitness (MAE) = 11.9052
#   Manta 16/50: Fitness (MAE) = 30.4523
#   Manta 17/50: Fitness (MAE) = 30.3299
#   Manta 18/50: Fitness (MAE) = 10.7690
#   Manta 19/50: Fitness (MAE) = 10.2516
#   Manta 20/50: Fitness (MAE) = 5.9946
#   Manta 21/50: Fitness (MAE) = 19.1623
#   Manta 22/50: Fitness (MAE) = 31.5908
#   Manta 23/50: Fitness (MAE) = 7.8856
#   Manta 24/50: Fitness (MAE) = 31.9956
#   Manta 25/50: Fitness (MAE) = 23.7460
#   Manta 26/50: Fitness (MAE) = 9.4782
#   Manta 27/50: Fitness (MAE) = 17.5765
#   Manta 28/50: Fitness (MAE) = 19.5155
#   Manta 29/50: Fitness (MAE) = 7.8901
#   Manta 30/50: Fitness (MAE) = 12.2389
#   Manta 31/50: Fitness (MAE) = 7.9254
#   Manta 32/50: Fitness (MAE) = 12.9601
#   Manta 33/50: Fitness (MAE) = 32.3014
#   Manta 34/50: Fitness (MAE) = 19.4057
#   Manta 35/50: Fitness (MAE) = 27.7546
#   Manta 36/50: Fitness (MAE) = 6.6258
#   Manta 37/50: Fitness (MAE) = 10.0152
#   Manta 38/50: Fitness (MAE) = 19.0213
#   Manta 39/50: Fitness (MAE) = 13.6410
#   Manta 40/50: Fitness (MAE) = 14.4771
#   Manta 41/50: Fitness (MAE) = 13.9193
#   Manta 42/50: Fitness (MAE) = 11.7095
#   Manta 43/50: Fitness (MAE) = 17.9012
#   Manta 44/50: Fitness (MAE) = 6.8463
#   Manta 45/50: Fitness (MAE) = 10.8981
#   Manta 46/50: Fitness (MAE) = 10.6966
#   Manta 47/50: Fitness (MAE) = 30.5763
#   Manta 48/50: Fitness (MAE) = 23.5251
#   Manta 49/50: Fitness (MAE) = 19.3145
#   Manta 50/50: Fitness (MAE) = 6.6198
# 🏃 View run MRFO_Iteration_2 at: http://localhost:5001/#/experiments/6/runs/7d58759123ce40caa37d23068ccff8d4
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
#
# Iteration 3/20
#   Manta 1/50: Fitness (MAE) = 27.9274
#   Manta 2/50: Fitness (MAE) = 11.1715
#   Manta 3/50: Fitness (MAE) = 7.3522
#   Manta 4/50: Fitness (MAE) = 9.9318
#   Manta 5/50: Fitness (MAE) = 9.8989
#   Manta 6/50: Fitness (MAE) = 9.7975
#   Manta 7/50: Fitness (MAE) = 21.2986
#   Manta 8/50: Fitness (MAE) = 13.8256
#   Manta 9/50: Fitness (MAE) = 7.6422
#   Manta 10/50: Fitness (MAE) = 6.5185
#   Manta 11/50: Fitness (MAE) = 38.2034
#   Manta 12/50: Fitness (MAE) = 40.4195
#   Manta 13/50: Fitness (MAE) = 8.3420
#   Manta 14/50: Fitness (MAE) = 9.3714
#   Manta 15/50: Fitness (MAE) = 15.4290
#   Manta 16/50: Fitness (MAE) = 20.3391
#   Manta 17/50: Fitness (MAE) = 9.9133
#   Manta 18/50: Fitness (MAE) = 31.2689
#   Manta 19/50: Fitness (MAE) = 31.2304
#   Manta 20/50: Fitness (MAE) = 16.9111
#   Manta 21/50: Fitness (MAE) = 14.0688
#   Manta 22/50: Fitness (MAE) = 5.9883
#   Manta 23/50: Fitness (MAE) = 17.3031
#   Manta 24/50: Fitness (MAE) = 35.7537
#   Manta 25/50: Fitness (MAE) = 14.3471
#   Manta 26/50: Fitness (MAE) = 9.4275
#   Manta 27/50: Fitness (MAE) = 8.3480
#   Manta 28/50: Fitness (MAE) = 9.3105
#   Manta 29/50: Fitness (MAE) = 9.5501
#   Manta 30/50: Fitness (MAE) = 10.7967
#   Manta 31/50: Fitness (MAE) = 16.4198
#   Manta 32/50: Fitness (MAE) = 16.9615
#   Manta 33/50: Fitness (MAE) = 14.0176
#   Manta 34/50: Fitness (MAE) = 9.7316
#   Manta 35/50: Fitness (MAE) = 23.4949
#   Manta 36/50: Fitness (MAE) = 12.6422
#   Manta 37/50: Fitness (MAE) = 22.3337
#   Manta 38/50: Fitness (MAE) = 9.1343
#   Manta 39/50: Fitness (MAE) = 7.6086
#   Manta 40/50: Fitness (MAE) = 48.4058
#   Manta 41/50: Fitness (MAE) = 12.8569
#   Manta 42/50: Fitness (MAE) = 18.7081
#   Manta 43/50: Fitness (MAE) = 13.7491
#   Manta 44/50: Fitness (MAE) = 14.4554
#   Manta 45/50: Fitness (MAE) = 46.1398
#   Manta 46/50: Fitness (MAE) = 15.2787
#   Manta 47/50: Fitness (MAE) = 8.4792
#   Manta 48/50: Fitness (MAE) = 8.2813
#   Manta 49/50: Fitness (MAE) = 8.4846
#   Manta 50/50: Fitness (MAE) = 14.7461
# 🏃 View run MRFO_Iteration_3 at: http://localhost:5001/#/experiments/6/runs/e444aef42b2346cc8469913a0cb1da61
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
#
# Iteration 4/20
#   Manta 1/50: Fitness (MAE) = 6.3987
#   Manta 2/50: Fitness (MAE) = 8.7747
#   Manta 3/50: Fitness (MAE) = 6.8072
#   Manta 4/50: Fitness (MAE) = 6.8950
#   Manta 5/50: Fitness (MAE) = 6.9152
#   Manta 6/50: Fitness (MAE) = 24.5482
#   Manta 7/50: Fitness (MAE) = 8.5531
#   Manta 8/50: Fitness (MAE) = 6.6486
#   Manta 9/50: Fitness (MAE) = 11.3072
#   Manta 10/50: Fitness (MAE) = 12.0563
#   Manta 11/50: Fitness (MAE) = 6.9755
#   Manta 12/50: Fitness (MAE) = 11.6529
#   Manta 13/50: Fitness (MAE) = 13.4870
#   Manta 14/50: Fitness (MAE) = 9.6700
#   Manta 15/50: Fitness (MAE) = 13.8978
#   Manta 16/50: Fitness (MAE) = 14.5572
#   Manta 17/50: Fitness (MAE) = 31.6948
#   Manta 18/50: Fitness (MAE) = 20.6965
#   Manta 19/50: Fitness (MAE) = 22.3472
#   Manta 20/50: Fitness (MAE) = 29.4132
#   Manta 21/50: Fitness (MAE) = 33.4331
#   Manta 22/50: Fitness (MAE) = 7.4936
#   Manta 23/50: Fitness (MAE) = 11.8920
#   Manta 24/50: Fitness (MAE) = 8.0505
#   Manta 25/50: Fitness (MAE) = 16.9796
#   Manta 26/50: Fitness (MAE) = 22.1214
#   Manta 27/50: Fitness (MAE) = 18.2794
#   Manta 28/50: Fitness (MAE) = 13.6673
#   Manta 29/50: Fitness (MAE) = 16.3557
#   Manta 30/50: Fitness (MAE) = 14.4802
#   Manta 31/50: Fitness (MAE) = 31.0240
#   Manta 32/50: Fitness (MAE) = 7.0617
#   Manta 33/50: Fitness (MAE) = 16.1746
#   Manta 34/50: Fitness (MAE) = 7.7890
#   Manta 35/50: Fitness (MAE) = 17.3157
#   Manta 36/50: Fitness (MAE) = 43.7317
#   Manta 37/50: Fitness (MAE) = 20.7752
#   Manta 38/50: Fitness (MAE) = 18.6474
#   Manta 39/50: Fitness (MAE) = 14.9737
#   Manta 40/50: Fitness (MAE) = 11.6653
#   Manta 41/50: Fitness (MAE) = 35.2293
#   Manta 42/50: Fitness (MAE) = 10.3899
#   Manta 43/50: Fitness (MAE) = 6.5075
#   Manta 44/50: Fitness (MAE) = 18.9849
#   Manta 45/50: Fitness (MAE) = 10.3211
#   Manta 46/50: Fitness (MAE) = 22.5672
#   Manta 47/50: Fitness (MAE) = 13.2087
#   Manta 48/50: Fitness (MAE) = 9.1025
#   Manta 49/50: Fitness (MAE) = 12.2790
#   Manta 50/50: Fitness (MAE) = 10.1131
# 🏃 View run MRFO_Iteration_4 at: http://localhost:5001/#/experiments/6/runs/96873ee23c9f409aaabe052e1f02cb77
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
#
# Iteration 5/20
#   Manta 1/50: Fitness (MAE) = 26.6538
#   Manta 2/50: Fitness (MAE) = 8.3502
#   Manta 3/50: Fitness (MAE) = 20.5411
#   Manta 4/50: Fitness (MAE) = 8.0725
#   Manta 5/50: Fitness (MAE) = 21.6784
#   Manta 6/50: Fitness (MAE) = 16.3083
#   Manta 7/50: Fitness (MAE) = 25.6541
#   Manta 8/50: Fitness (MAE) = 16.3374
#   Manta 9/50: Fitness (MAE) = 19.8884
#   Manta 10/50: Fitness (MAE) = 7.1772
#   Manta 11/50: Fitness (MAE) = 16.8601
#   Manta 12/50: Fitness (MAE) = 14.6267
#   Manta 13/50: Fitness (MAE) = 11.4293
#   Manta 14/50: Fitness (MAE) = 9.5965
#   Manta 15/50: Fitness (MAE) = 12.7628
#   Manta 16/50: Fitness (MAE) = 32.5515
#   Manta 17/50: Fitness (MAE) = 9.9722
#   Manta 18/50: Fitness (MAE) = 11.4018
#   Manta 19/50: Fitness (MAE) = 11.8240
#   Manta 20/50: Fitness (MAE) = 8.9030
#   Manta 21/50: Fitness (MAE) = 16.5054
#   Manta 22/50: Fitness (MAE) = 25.4872
#   Manta 23/50: Fitness (MAE) = 36.2241
#   Manta 24/50: Fitness (MAE) = 12.8566
#   Manta 25/50: Fitness (MAE) = 16.4769
#   Manta 26/50: Fitness (MAE) = 7.7325
#   Manta 27/50: Fitness (MAE) = 16.1954
#   Manta 28/50: Fitness (MAE) = 11.5547
#   Manta 29/50: Fitness (MAE) = 13.3650
#   Manta 30/50: Fitness (MAE) = 29.8609
#   Manta 31/50: Fitness (MAE) = 29.1274
#   Manta 32/50: Fitness (MAE) = 20.3104
#   Manta 33/50: Fitness (MAE) = 33.5742
#   Manta 34/50: Fitness (MAE) = 8.0193
#   Manta 35/50: Fitness (MAE) = 6.2522
#   Manta 36/50: Fitness (MAE) = 16.4517
#   Manta 37/50: Fitness (MAE) = 15.3175
#   Manta 38/50: Fitness (MAE) = 7.2714
#   Manta 39/50: Fitness (MAE) = 16.1380
#   Manta 40/50: Fitness (MAE) = 7.3247
#   Manta 41/50: Fitness (MAE) = 6.6841
#   Manta 42/50: Fitness (MAE) = 28.8493
#   Manta 43/50: Fitness (MAE) = 6.8487
#   Manta 44/50: Fitness (MAE) = 10.8586
#   Manta 45/50: Fitness (MAE) = 19.0739
#   Manta 46/50: Fitness (MAE) = 27.9224
#   Manta 47/50: Fitness (MAE) = 29.7864
#   Manta 48/50: Fitness (MAE) = 15.8741
#   Manta 49/50: Fitness (MAE) = 16.3259
#   Manta 50/50: Fitness (MAE) = 19.0235
# 🏃 View run MRFO_Iteration_5 at: http://localhost:5001/#/experiments/6/runs/49400c51a1684409bf71efc09e36bf05
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
#
# Iteration 6/20
#   Manta 1/50: Fitness (MAE) = 17.0247
#   Manta 2/50: Fitness (MAE) = 16.8357
#   Manta 3/50: Fitness (MAE) = 15.9721
#   Manta 4/50: Fitness (MAE) = 15.4538
#   Manta 5/50: Fitness (MAE) = 12.4272
#   Manta 6/50: Fitness (MAE) = 7.0698
#   Manta 7/50: Fitness (MAE) = 24.9835
#   Manta 8/50: Fitness (MAE) = 20.9685
#   Manta 9/50: Fitness (MAE) = 20.1803
#   Manta 10/50: Fitness (MAE) = 8.3310
#   Manta 11/50: Fitness (MAE) = 13.6313
#   Manta 12/50: Fitness (MAE) = 19.2781
#   Manta 13/50: Fitness (MAE) = 10.3008
#   Manta 14/50: Fitness (MAE) = 6.6511
#   Manta 15/50: Fitness (MAE) = 15.0777
#   Manta 16/50: Fitness (MAE) = 6.9621
#   Manta 17/50: Fitness (MAE) = 26.9502
#   Manta 18/50: Fitness (MAE) = 11.3735
#   Manta 19/50: Fitness (MAE) = 8.7767
#   Manta 20/50: Fitness (MAE) = 9.3611
#   Manta 21/50: Fitness (MAE) = 11.9723
#   Manta 22/50: Fitness (MAE) = 34.0396
#   Manta 23/50: Fitness (MAE) = 16.7689
#   Manta 24/50: Fitness (MAE) = 7.6109
#   Manta 25/50: Fitness (MAE) = 12.2322
#   Manta 26/50: Fitness (MAE) = 32.2291
#   Manta 27/50: Fitness (MAE) = 7.5280
#   Manta 28/50: Fitness (MAE) = 17.0671
#   Manta 29/50: Fitness (MAE) = 15.3069
#   Manta 30/50: Fitness (MAE) = 7.7819
#   Manta 31/50: Fitness (MAE) = 6.4444
#   Manta 32/50: Fitness (MAE) = 8.0781
#   Manta 33/50: Fitness (MAE) = 12.6573
#   Manta 34/50: Fitness (MAE) = 19.9995
#   Manta 35/50: Fitness (MAE) = 11.7160
#   Manta 36/50: Fitness (MAE) = 32.2745
#   Manta 37/50: Fitness (MAE) = 8.1651
#   Manta 38/50: Fitness (MAE) = 23.6869
#   Manta 39/50: Fitness (MAE) = 23.1003
#   Manta 40/50: Fitness (MAE) = 7.4655
#   Manta 41/50: Fitness (MAE) = 11.3622
#   Manta 42/50: Fitness (MAE) = 20.8028
#   Manta 43/50: Fitness (MAE) = 15.5139
#   Manta 44/50: Fitness (MAE) = 6.5859
#   Manta 45/50: Fitness (MAE) = 19.1419
#   Manta 46/50: Fitness (MAE) = 10.3067
#   Manta 47/50: Fitness (MAE) = 18.8607
#   Manta 48/50: Fitness (MAE) = 11.6027
#   Manta 49/50: Fitness (MAE) = 31.0523
#   Manta 50/50: Fitness (MAE) = 12.6929
# 🏃 View run MRFO_Iteration_6 at: http://localhost:5001/#/experiments/6/runs/2c9095a94db243189916ae5e62f3c22b
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
#
# Iteration 7/20
#   Manta 1/50: Fitness (MAE) = 8.3441
#   Manta 2/50: Fitness (MAE) = 6.5194
#   Manta 3/50: Fitness (MAE) = 16.3110
#   Manta 4/50: Fitness (MAE) = 24.8085
#   Manta 5/50: Fitness (MAE) = 11.3761
#   Manta 6/50: Fitness (MAE) = 11.9788
#   Manta 7/50: Fitness (MAE) = 29.4184
#   Manta 8/50: Fitness (MAE) = 26.0354
#   Manta 9/50: Fitness (MAE) = 7.0836
#   Manta 10/50: Fitness (MAE) = 21.0190
#   Manta 11/50: Fitness (MAE) = 6.7869
#   Manta 12/50: Fitness (MAE) = 31.3951
#   Manta 13/50: Fitness (MAE) = 14.9232
#   Manta 14/50: Fitness (MAE) = 24.6306
#   Manta 15/50: Fitness (MAE) = 41.6388
#   Manta 16/50: Fitness (MAE) = 8.6313
#   Manta 17/50: Fitness (MAE) = 19.7107
#   Manta 18/50: Fitness (MAE) = 27.8527
#   Manta 19/50: Fitness (MAE) = 9.6771
#   Manta 20/50: Fitness (MAE) = 6.1130
#   Manta 21/50: Fitness (MAE) = 6.4052
#   Manta 22/50: Fitness (MAE) = 31.5941
#   Manta 23/50: Fitness (MAE) = 7.1347
#   Manta 24/50: Fitness (MAE) = 33.5786
#   Manta 25/50: Fitness (MAE) = 44.9264
#   Manta 26/50: Fitness (MAE) = 6.3529
#   Manta 27/50: Fitness (MAE) = 16.3459
#   Manta 28/50: Fitness (MAE) = 8.9186
#   Manta 29/50: Fitness (MAE) = 15.7044
#   Manta 30/50: Fitness (MAE) = 20.8109
#   Manta 31/50: Fitness (MAE) = 9.0581
#   Manta 32/50: Fitness (MAE) = 12.5425
#   Manta 33/50: Fitness (MAE) = 12.9167
#   Manta 34/50: Fitness (MAE) = 13.3256
#   Manta 35/50: Fitness (MAE) = 17.4806
#   Manta 36/50: Fitness (MAE) = 35.3162
#   Manta 37/50: Fitness (MAE) = 23.5001
#   Manta 38/50: Fitness (MAE) = 14.4790
#   Manta 39/50: Fitness (MAE) = 15.9978
#   Manta 40/50: Fitness (MAE) = 15.6823
#   Manta 41/50: Fitness (MAE) = 7.6981
#   Manta 42/50: Fitness (MAE) = 12.8812
#   Manta 43/50: Fitness (MAE) = 13.5791
#   Manta 44/50: Fitness (MAE) = 31.5730
#   Manta 45/50: Fitness (MAE) = 16.1643
#   Manta 46/50: Fitness (MAE) = 7.0210
#   Manta 47/50: Fitness (MAE) = 12.7015
#   Manta 48/50: Fitness (MAE) = 31.8782
#   Manta 49/50: Fitness (MAE) = 8.5264
#   Manta 50/50: Fitness (MAE) = 23.7396
# 🏃 View run MRFO_Iteration_7 at: http://localhost:5001/#/experiments/6/runs/2eb25fa2dbaa4ecba9b11669c2e6ce3b
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
#
# Iteration 8/20
#   Manta 1/50: Fitness (MAE) = 13.5223
#   Manta 2/50: Fitness (MAE) = 15.4892
#   Manta 3/50: Fitness (MAE) = 12.6005
#   Manta 4/50: Fitness (MAE) = 12.3549
#   Manta 5/50: Fitness (MAE) = 6.9648
#   Manta 6/50: Fitness (MAE) = 16.8629
#   Manta 7/50: Fitness (MAE) = 12.3274
#   Manta 8/50: Fitness (MAE) = 12.9430
#   Manta 9/50: Fitness (MAE) = 5.8725
#   Manta 10/50: Fitness (MAE) = 6.9663
#   Manta 11/50: Fitness (MAE) = 14.1281
#   Manta 12/50: Fitness (MAE) = 30.3181
#   Manta 13/50: Fitness (MAE) = 12.7134
#   Manta 14/50: Fitness (MAE) = 14.8301
#   Manta 15/50: Fitness (MAE) = 9.4966
#   Manta 16/50: Fitness (MAE) = 15.1965
#   Manta 17/50: Fitness (MAE) = 17.4474
#   Manta 18/50: Fitness (MAE) = 12.0765
#   Manta 19/50: Fitness (MAE) = 15.6670
#   Manta 20/50: Fitness (MAE) = 9.8754
#   Manta 21/50: Fitness (MAE) = 13.3267
#   Manta 22/50: Fitness (MAE) = 20.1463
#   Manta 23/50: Fitness (MAE) = 12.6573
#   Manta 24/50: Fitness (MAE) = 8.0083
#   Manta 25/50: Fitness (MAE) = 25.8464
#   Manta 26/50: Fitness (MAE) = 11.4463
#   Manta 27/50: Fitness (MAE) = 9.3498
#   Manta 28/50: Fitness (MAE) = 10.7048
#   Manta 29/50: Fitness (MAE) = 7.5458
#   Manta 30/50: Fitness (MAE) = 9.9818
#   Manta 31/50: Fitness (MAE) = 7.4179
#   Manta 32/50: Fitness (MAE) = 8.3898
#   Manta 33/50: Fitness (MAE) = 18.6890
#   Manta 34/50: Fitness (MAE) = 7.8801
#   Manta 35/50: Fitness (MAE) = 8.9641
#   Manta 36/50: Fitness (MAE) = 11.2220
#   Manta 37/50: Fitness (MAE) = 23.3879
#   Manta 38/50: Fitness (MAE) = 12.0637
#   Manta 39/50: Fitness (MAE) = 11.7097
#   Manta 40/50: Fitness (MAE) = 19.6459
#   Manta 41/50: Fitness (MAE) = 16.7094
#   Manta 42/50: Fitness (MAE) = 6.9143
#   Manta 43/50: Fitness (MAE) = 8.2360
#   Manta 44/50: Fitness (MAE) = 24.9686
#   Manta 45/50: Fitness (MAE) = 18.2307
#   Manta 46/50: Fitness (MAE) = 15.9072
#   Manta 47/50: Fitness (MAE) = 8.5342
#   Manta 48/50: Fitness (MAE) = 37.4322
#   Manta 49/50: Fitness (MAE) = 19.5540
#   Manta 50/50: Fitness (MAE) = 16.1875
# 🏃 View run MRFO_Iteration_8 at: http://localhost:5001/#/experiments/6/runs/4e2509d23f144c2fa21839a082fb0364
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
#
# Iteration 9/20
#   Manta 1/50: Fitness (MAE) = 19.5286
#   Manta 2/50: Fitness (MAE) = 13.2195
#   Manta 3/50: Fitness (MAE) = 11.7167
#   Manta 4/50: Fitness (MAE) = 11.8051
#   Manta 5/50: Fitness (MAE) = 10.0998
#   Manta 6/50: Fitness (MAE) = 6.5932
#   Manta 7/50: Fitness (MAE) = 16.4850
#   Manta 8/50: Fitness (MAE) = 8.4260
#   Manta 9/50: Fitness (MAE) = 20.5293
#   Manta 10/50: Fitness (MAE) = 44.9284
#   Manta 11/50: Fitness (MAE) = 8.5385
#   Manta 12/50: Fitness (MAE) = 15.4821
#   Manta 13/50: Fitness (MAE) = 8.1600
#   Manta 14/50: Fitness (MAE) = 13.2752
#   Manta 15/50: Fitness (MAE) = 7.1281
#   Manta 16/50: Fitness (MAE) = 17.8003
#   Manta 17/50: Fitness (MAE) = 7.0731
#   Manta 18/50: Fitness (MAE) = 44.5018
#   Manta 19/50: Fitness (MAE) = 7.0872
#   Manta 20/50: Fitness (MAE) = 33.0746
#   Manta 21/50: Fitness (MAE) = 10.7922
#   Manta 22/50: Fitness (MAE) = 11.9706
#   Manta 23/50: Fitness (MAE) = 18.2143
#   Manta 24/50: Fitness (MAE) = 18.5416
#   Manta 25/50: Fitness (MAE) = 23.1771
#   Manta 26/50: Fitness (MAE) = 19.4324
#   Manta 27/50: Fitness (MAE) = 7.6440
#   Manta 28/50: Fitness (MAE) = 21.9696
#   Manta 29/50: Fitness (MAE) = 7.3805
#   Manta 30/50: Fitness (MAE) = 9.2654
#   Manta 31/50: Fitness (MAE) = 6.6442
#   Manta 32/50: Fitness (MAE) = 9.3242
#   Manta 33/50: Fitness (MAE) = 12.0354
#   Manta 34/50: Fitness (MAE) = 9.5152
#   Manta 35/50: Fitness (MAE) = 16.6642
#   Manta 36/50: Fitness (MAE) = 16.2615
#   Manta 37/50: Fitness (MAE) = 18.6705
#   Manta 38/50: Fitness (MAE) = 9.7604
#   Manta 39/50: Fitness (MAE) = 17.1923
#   Manta 40/50: Fitness (MAE) = 8.3148
#   Manta 41/50: Fitness (MAE) = 11.4760
#   Manta 42/50: Fitness (MAE) = 32.9225
#   Manta 43/50: Fitness (MAE) = 14.6634
#   Manta 44/50: Fitness (MAE) = 28.3058
#   Manta 45/50: Fitness (MAE) = 14.0772
#   Manta 46/50: Fitness (MAE) = 10.8023
#   Manta 47/50: Fitness (MAE) = 9.8398
#   Manta 48/50: Fitness (MAE) = 16.4595
#   Manta 49/50: Fitness (MAE) = 16.1250
#   Manta 50/50: Fitness (MAE) = 26.2797
# 🏃 View run MRFO_Iteration_9 at: http://localhost:5001/#/experiments/6/runs/9766c97c890a4da9b8e69eefd55f174c
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
#
# Iteration 10/20
#   Manta 1/50: Fitness (MAE) = 17.5837
#   Manta 2/50: Fitness (MAE) = 8.1542
#   Manta 3/50: Fitness (MAE) = 9.1805
#   Manta 4/50: Fitness (MAE) = 19.9719
#   Manta 5/50: Fitness (MAE) = 8.2801
#   Manta 6/50: Fitness (MAE) = 33.4393
#   Manta 7/50: Fitness (MAE) = 11.4520
#   Manta 8/50: Fitness (MAE) = 27.0757
#   Manta 9/50: Fitness (MAE) = 8.1589
#   Manta 10/50: Fitness (MAE) = 8.6921
#   Manta 11/50: Fitness (MAE) = 19.2455
#   Manta 12/50: Fitness (MAE) = 17.7822
#   Manta 13/50: Fitness (MAE) = 9.8747
#   Manta 14/50: Fitness (MAE) = 6.1624
#   Manta 15/50: Fitness (MAE) = 34.0401
#   Manta 16/50: Fitness (MAE) = 7.4507
#   Manta 17/50: Fitness (MAE) = 11.8586
#   Manta 18/50: Fitness (MAE) = 10.7666
#   Manta 19/50: Fitness (MAE) = 19.7701
#   Manta 20/50: Fitness (MAE) = 7.1948
#   Manta 21/50: Fitness (MAE) = 8.6054
#   Manta 22/50: Fitness (MAE) = 26.6651
#   Manta 23/50: Fitness (MAE) = 7.4354
#   Manta 24/50: Fitness (MAE) = 10.9961
#   Manta 25/50: Fitness (MAE) = 8.8312
#   Manta 26/50: Fitness (MAE) = 17.6372
#   Manta 27/50: Fitness (MAE) = 10.8187
#   Manta 28/50: Fitness (MAE) = 10.6560
#   Manta 29/50: Fitness (MAE) = 8.4686
#   Manta 30/50: Fitness (MAE) = 8.8476
#   Manta 31/50: Fitness (MAE) = 7.1691
#   Manta 32/50: Fitness (MAE) = 14.0895
#   Manta 33/50: Fitness (MAE) = 8.1744
#   Manta 34/50: Fitness (MAE) = 35.8848
#   Manta 35/50: Fitness (MAE) = 6.6101
#   Manta 36/50: Fitness (MAE) = 8.8973
#   Manta 37/50: Fitness (MAE) = 21.5755
#   Manta 38/50: Fitness (MAE) = 31.3543
#   Manta 39/50: Fitness (MAE) = 14.2183
#   Manta 40/50: Fitness (MAE) = 6.1481
#   Manta 41/50: Fitness (MAE) = 14.6018
#   Manta 42/50: Fitness (MAE) = 7.4169
#   Manta 43/50: Fitness (MAE) = 29.7072
#   Manta 44/50: Fitness (MAE) = 18.1713
#   Manta 45/50: Fitness (MAE) = 19.7639
#   Manta 46/50: Fitness (MAE) = 23.7306
#   Manta 47/50: Fitness (MAE) = 16.0106
#   Manta 48/50: Fitness (MAE) = 11.8352
#   Manta 49/50: Fitness (MAE) = 9.5179
#   Manta 50/50: Fitness (MAE) = 12.7153
# 🏃 View run MRFO_Iteration_10 at: http://localhost:5001/#/experiments/6/runs/ff6edc8bd7ba41a68c2305e6fff4688b
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
#
# Iteration 11/20
#   Manta 1/50: Fitness (MAE) = 9.8709
#   Manta 2/50: Fitness (MAE) = 15.6691
#   Manta 3/50: Fitness (MAE) = 8.4627
#   Manta 4/50: Fitness (MAE) = 21.4143
#   Manta 5/50: Fitness (MAE) = 7.9888
#   Manta 6/50: Fitness (MAE) = 7.1926
#   Manta 7/50: Fitness (MAE) = 19.9980
#   Manta 8/50: Fitness (MAE) = 12.3664
#   Manta 9/50: Fitness (MAE) = 6.8931
#   Manta 10/50: Fitness (MAE) = 19.7524
#   Manta 11/50: Fitness (MAE) = 12.6803
#   Manta 12/50: Fitness (MAE) = 11.6195
#   Manta 13/50: Fitness (MAE) = 18.8605
#   Manta 14/50: Fitness (MAE) = 16.5755
#   Manta 15/50: Fitness (MAE) = 45.0464
#   Manta 16/50: Fitness (MAE) = 11.4173
#   Manta 17/50: Fitness (MAE) = 30.2684
#   Manta 18/50: Fitness (MAE) = 15.2217
#   Manta 19/50: Fitness (MAE) = 31.7100
#   Manta 20/50: Fitness (MAE) = 7.2022
#   Manta 21/50: Fitness (MAE) = 26.9609
#   Manta 22/50: Fitness (MAE) = 11.8164
#   Manta 23/50: Fitness (MAE) = 12.9217
#   Manta 24/50: Fitness (MAE) = 26.7254
#   Manta 25/50: Fitness (MAE) = 6.2551
#   Manta 26/50: Fitness (MAE) = 17.9057
#   Manta 27/50: Fitness (MAE) = 32.6423
#   Manta 28/50: Fitness (MAE) = 14.2540
#   Manta 29/50: Fitness (MAE) = 14.9200
#   Manta 30/50: Fitness (MAE) = 14.5967
#   Manta 31/50: Fitness (MAE) = 27.3840
#   Manta 32/50: Fitness (MAE) = 10.6614
#   Manta 33/50: Fitness (MAE) = 12.1019
#   Manta 34/50: Fitness (MAE) = 15.3682
#   Manta 35/50: Fitness (MAE) = 8.1483
#   Manta 36/50: Fitness (MAE) = 9.5468
#   Manta 37/50: Fitness (MAE) = 12.0029
#   Manta 38/50: Fitness (MAE) = 31.6226
#   Manta 39/50: Fitness (MAE) = 6.7656
#   Manta 40/50: Fitness (MAE) = 9.8443
#   Manta 41/50: Fitness (MAE) = 21.9067
#   Manta 42/50: Fitness (MAE) = 33.6343
#   Manta 43/50: Fitness (MAE) = 7.9534
#   Manta 44/50: Fitness (MAE) = 17.7278
#   Manta 45/50: Fitness (MAE) = 9.2144
#   Manta 46/50: Fitness (MAE) = 12.3861
#   Manta 47/50: Fitness (MAE) = 12.9733
#   Manta 48/50: Fitness (MAE) = 42.9768
#   Manta 49/50: Fitness (MAE) = 6.0323
#   Manta 50/50: Fitness (MAE) = 7.6970
# 🏃 View run MRFO_Iteration_11 at: http://localhost:5001/#/experiments/6/runs/a17f11541fc04327a7771b1006f9df57
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
#
# Iteration 12/20
#   Manta 1/50: Fitness (MAE) = 20.3555
#   Manta 2/50: Fitness (MAE) = 15.6600
#   Manta 3/50: Fitness (MAE) = 9.8125
#   Manta 4/50: Fitness (MAE) = 15.9337
#   Manta 5/50: Fitness (MAE) = 7.3051
#   Manta 6/50: Fitness (MAE) = 15.0457
#   Manta 7/50: Fitness (MAE) = 14.2641
#   Manta 8/50: Fitness (MAE) = 14.7300
#   Manta 9/50: Fitness (MAE) = 18.2387
#   Manta 10/50: Fitness (MAE) = 13.0522
#   Manta 11/50: Fitness (MAE) = 9.4474
#   Manta 12/50: Fitness (MAE) = 44.5008
#   Manta 13/50: Fitness (MAE) = 9.3514
#   Manta 14/50: Fitness (MAE) = 8.2625
#   Manta 15/50: Fitness (MAE) = 41.8768
#   Manta 16/50: Fitness (MAE) = 12.5801
#   Manta 17/50: Fitness (MAE) = 32.2516
#   Manta 18/50: Fitness (MAE) = 21.2651
#   Manta 19/50: Fitness (MAE) = 14.5541
#   Manta 20/50: Fitness (MAE) = 13.2362
#   Manta 21/50: Fitness (MAE) = 11.0642
#   Manta 22/50: Fitness (MAE) = 30.7958
#   Manta 23/50: Fitness (MAE) = 17.0407
#   Manta 24/50: Fitness (MAE) = 20.8891
#   Manta 25/50: Fitness (MAE) = 48.8731
#   Manta 26/50: Fitness (MAE) = 45.2572
#   Manta 27/50: Fitness (MAE) = 13.7720
#   Manta 28/50: Fitness (MAE) = 31.6085
#   Manta 29/50: Fitness (MAE) = 12.8594
#   Manta 30/50: Fitness (MAE) = 19.3861
#   Manta 31/50: Fitness (MAE) = 44.7330
#   Manta 32/50: Fitness (MAE) = 29.0468
#   Manta 33/50: Fitness (MAE) = 26.9099
#   Manta 34/50: Fitness (MAE) = 7.6846
#   Manta 35/50: Fitness (MAE) = 22.5644
#   Manta 36/50: Fitness (MAE) = 18.6267
#   Manta 37/50: Fitness (MAE) = 7.0744
#   Manta 38/50: Fitness (MAE) = 14.0844
#   Manta 39/50: Fitness (MAE) = 13.5574
#   Manta 40/50: Fitness (MAE) = 25.6104
#   Manta 41/50: Fitness (MAE) = 26.6179
#   Manta 42/50: Fitness (MAE) = 14.2970
#   Manta 43/50: Fitness (MAE) = 14.1029
#   Manta 44/50: Fitness (MAE) = 15.3008
#   Manta 45/50: Fitness (MAE) = 16.8385
#   Manta 46/50: Fitness (MAE) = 7.3090
#   Manta 47/50: Fitness (MAE) = 18.4153
#   Manta 48/50: Fitness (MAE) = 15.6843
#   Manta 49/50: Fitness (MAE) = 21.7155
#   Manta 50/50: Fitness (MAE) = 11.7387
# 🏃 View run MRFO_Iteration_12 at: http://localhost:5001/#/experiments/6/runs/d89f3640b26f486384989cb85466efbe
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
#
# Iteration 13/20
#   Manta 1/50: Fitness (MAE) = 20.0104
#   Manta 2/50: Fitness (MAE) = 14.9303
#   Manta 3/50: Fitness (MAE) = 6.5616
#   Manta 4/50: Fitness (MAE) = 9.2116
#   Manta 5/50: Fitness (MAE) = 26.5891
#   Manta 6/50: Fitness (MAE) = 8.5804
#   Manta 7/50: Fitness (MAE) = 9.2784
#   Manta 8/50: Fitness (MAE) = 31.8632
#   Manta 9/50: Fitness (MAE) = 23.2717
#   Manta 10/50: Fitness (MAE) = 12.2202
#   Manta 11/50: Fitness (MAE) = 7.6234
#   Manta 12/50: Fitness (MAE) = 41.4618
#   Manta 13/50: Fitness (MAE) = 21.7632
#   Manta 14/50: Fitness (MAE) = 11.3206
#   Manta 15/50: Fitness (MAE) = 14.3159
#   Manta 16/50: Fitness (MAE) = 8.2268
#   Manta 17/50: Fitness (MAE) = 9.3635
#   Manta 18/50: Fitness (MAE) = 19.7276
#   Manta 19/50: Fitness (MAE) = 21.1878
#   Manta 20/50: Fitness (MAE) = 15.8068
#   Manta 21/50: Fitness (MAE) = 14.6432
#   Manta 22/50: Fitness (MAE) = 11.8408
#   Manta 23/50: Fitness (MAE) = 13.5679
#   Manta 24/50: Fitness (MAE) = 11.0797
#   Manta 25/50: Fitness (MAE) = 30.4013
#   Manta 26/50: Fitness (MAE) = 19.3795
#   Manta 27/50: Fitness (MAE) = 8.4936
#   Manta 28/50: Fitness (MAE) = 7.5344
#   Manta 29/50: Fitness (MAE) = 7.9779
#   Manta 30/50: Fitness (MAE) = 8.9178
#   Manta 31/50: Fitness (MAE) = 15.7159
#   Manta 32/50: Fitness (MAE) = 15.0501
#   Manta 33/50: Fitness (MAE) = 12.9111
#   Manta 34/50: Fitness (MAE) = 12.9746
#   Manta 35/50: Fitness (MAE) = 11.7701
#   Manta 36/50: Fitness (MAE) = 13.0621
#   Manta 37/50: Fitness (MAE) = 17.4543
#   Manta 38/50: Fitness (MAE) = 21.1111
#   Manta 39/50: Fitness (MAE) = 7.0085
#   Manta 40/50: Fitness (MAE) = 35.2291
#   Manta 41/50: Fitness (MAE) = 11.6145
#   Manta 42/50: Fitness (MAE) = 13.7287
#   Manta 43/50: Fitness (MAE) = 13.2414
#   Manta 44/50: Fitness (MAE) = 13.2895
#   Manta 45/50: Fitness (MAE) = 7.1447
#   Manta 46/50: Fitness (MAE) = 29.7063
#   Manta 47/50: Fitness (MAE) = 7.7827
#   Manta 48/50: Fitness (MAE) = 14.6976
#   Manta 49/50: Fitness (MAE) = 6.7846
#   Manta 50/50: Fitness (MAE) = 10.5263
# 🏃 View run MRFO_Iteration_13 at: http://localhost:5001/#/experiments/6/runs/f48307a900184fa889f28bb3d33f16db
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
#
# Iteration 14/20
#   Manta 1/50: Fitness (MAE) = 10.4740
#   Manta 2/50: Fitness (MAE) = 13.2524
#   Manta 3/50: Fitness (MAE) = 10.6723
#   Manta 4/50: Fitness (MAE) = 6.3654
#   Manta 5/50: Fitness (MAE) = 8.5224
#   Manta 6/50: Fitness (MAE) = 16.8247
#   Manta 7/50: Fitness (MAE) = 21.5767
#   Manta 8/50: Fitness (MAE) = 9.8527
#   Manta 9/50: Fitness (MAE) = 14.1403
#   Manta 10/50: Fitness (MAE) = 6.4610
#   Manta 11/50: Fitness (MAE) = 10.1950
#   Manta 12/50: Fitness (MAE) = 9.7347
#   Manta 13/50: Fitness (MAE) = 14.1972
#   Manta 14/50: Fitness (MAE) = 17.2487
#   Manta 15/50: Fitness (MAE) = 16.7864
#   Manta 16/50: Fitness (MAE) = 7.6788
#   Manta 17/50: Fitness (MAE) = 13.4086
#   Manta 18/50: Fitness (MAE) = 15.0889
#   Manta 19/50: Fitness (MAE) = 8.4025
#   Manta 20/50: Fitness (MAE) = 16.9325
#   Manta 21/50: Fitness (MAE) = 14.8150
#   Manta 22/50: Fitness (MAE) = 31.7763
#   Manta 23/50: Fitness (MAE) = 11.3674
#   Manta 24/50: Fitness (MAE) = 7.1330
#   Manta 25/50: Fitness (MAE) = 14.3767
#   Manta 26/50: Fitness (MAE) = 6.6199
#   Manta 27/50: Fitness (MAE) = 33.8989
#   Manta 28/50: Fitness (MAE) = 19.2393
#   Manta 29/50: Fitness (MAE) = 39.4083
#   Manta 30/50: Fitness (MAE) = 13.1846
#   Manta 31/50: Fitness (MAE) = 16.4681
#   Manta 32/50: Fitness (MAE) = 8.1392
#   Manta 33/50: Fitness (MAE) = 7.6864
#   Manta 34/50: Fitness (MAE) = 17.6436
#   Manta 35/50: Fitness (MAE) = 8.2671
#   Manta 36/50: Fitness (MAE) = 31.9011
#   Manta 37/50: Fitness (MAE) = 23.8157
#   Manta 38/50: Fitness (MAE) = 17.3350
#   Manta 39/50: Fitness (MAE) = 6.5423
#   Manta 40/50: Fitness (MAE) = 11.5600
#   Manta 41/50: Fitness (MAE) = 14.5614
#   Manta 42/50: Fitness (MAE) = 7.7455
#   Manta 43/50: Fitness (MAE) = 14.5536
#   Manta 44/50: Fitness (MAE) = 9.4326
#   Manta 45/50: Fitness (MAE) = 10.3723
#   Manta 46/50: Fitness (MAE) = 15.3906
#   Manta 47/50: Fitness (MAE) = 14.6344
#   Manta 48/50: Fitness (MAE) = 21.8010
#   Manta 49/50: Fitness (MAE) = 12.3716
#   Manta 50/50: Fitness (MAE) = 20.7586
# 🏃 View run MRFO_Iteration_14 at: http://localhost:5001/#/experiments/6/runs/01f98ceae1154ea5b7dd709360bcc5db
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
#
# Iteration 15/20
#   Manta 1/50: Fitness (MAE) = 34.5639
#   Manta 2/50: Fitness (MAE) = 31.2941
#   Manta 3/50: Fitness (MAE) = 10.0115
#   Manta 4/50: Fitness (MAE) = 19.2513
#   Manta 5/50: Fitness (MAE) = 7.5879
#   Manta 6/50: Fitness (MAE) = 12.2078
#   Manta 7/50: Fitness (MAE) = 17.7865
#   Manta 8/50: Fitness (MAE) = 36.5086
#   Manta 9/50: Fitness (MAE) = 6.8261
#   Manta 10/50: Fitness (MAE) = 18.0659
#   Manta 11/50: Fitness (MAE) = 7.2226
#   Manta 12/50: Fitness (MAE) = 8.9752
#   Manta 13/50: Fitness (MAE) = 7.9795
#   Manta 14/50: Fitness (MAE) = 7.0872
#   Manta 15/50: Fitness (MAE) = 9.3774
#   Manta 16/50: Fitness (MAE) = 26.3335
#   Manta 17/50: Fitness (MAE) = 24.8856
#   Manta 18/50: Fitness (MAE) = 7.1036
#   Manta 19/50: Fitness (MAE) = 41.2718
#   Manta 20/50: Fitness (MAE) = 8.9186
#   Manta 21/50: Fitness (MAE) = 17.0184
#   Manta 22/50: Fitness (MAE) = 18.5530
#   Manta 23/50: Fitness (MAE) = 10.6780
#   Manta 24/50: Fitness (MAE) = 17.5653
#   Manta 25/50: Fitness (MAE) = 16.6099
#   Manta 26/50: Fitness (MAE) = 30.2146
#   Manta 27/50: Fitness (MAE) = 15.4216
#   Manta 28/50: Fitness (MAE) = 14.0305
#   Manta 29/50: Fitness (MAE) = 12.8972
#   Manta 30/50: Fitness (MAE) = 7.3897
#   Manta 31/50: Fitness (MAE) = 28.2086
#   Manta 32/50: Fitness (MAE) = 18.8329
#   Manta 33/50: Fitness (MAE) = 7.6783
#   Manta 34/50: Fitness (MAE) = 6.8534
#   Manta 35/50: Fitness (MAE) = 8.0623
#   Manta 36/50: Fitness (MAE) = 19.5588
#   Manta 37/50: Fitness (MAE) = 9.6080
#   Manta 38/50: Fitness (MAE) = 12.3646
#   Manta 39/50: Fitness (MAE) = 21.2918
#   Manta 40/50: Fitness (MAE) = 29.4929
#   Manta 41/50: Fitness (MAE) = 9.3885
#   Manta 42/50: Fitness (MAE) = 32.8603
#   Manta 43/50: Fitness (MAE) = 7.8020
#   Manta 44/50: Fitness (MAE) = 15.6127
#   Manta 45/50: Fitness (MAE) = 13.2833
#   Manta 46/50: Fitness (MAE) = 16.9615
#   Manta 47/50: Fitness (MAE) = 7.3779
#   Manta 48/50: Fitness (MAE) = 11.6036
#   Manta 49/50: Fitness (MAE) = 28.8403
#   Manta 50/50: Fitness (MAE) = 31.3551
# 🏃 View run MRFO_Iteration_15 at: http://localhost:5001/#/experiments/6/runs/c46add5c4aae429e89437c7184150c06
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
#
# Iteration 16/20
#   Manta 1/50: Fitness (MAE) = 6.6645
#   Manta 2/50: Fitness (MAE) = 12.7485
#   Manta 3/50: Fitness (MAE) = 17.4371
#   Manta 4/50: Fitness (MAE) = 14.4647
#   Manta 5/50: Fitness (MAE) = 17.0983
#   Manta 6/50: Fitness (MAE) = 12.6557
#   Manta 7/50: Fitness (MAE) = 8.1394
#   Manta 8/50: Fitness (MAE) = 22.5419
#   Manta 9/50: Fitness (MAE) = 12.1221
#   Manta 10/50: Fitness (MAE) = 9.0980
#   Manta 11/50: Fitness (MAE) = 6.8496
#   Manta 12/50: Fitness (MAE) = 36.3128
#   Manta 13/50: Fitness (MAE) = 17.8176
#   Manta 14/50: Fitness (MAE) = 12.4820
#   Manta 15/50: Fitness (MAE) = 8.0375
#   Manta 16/50: Fitness (MAE) = 30.8311
#   Manta 17/50: Fitness (MAE) = 7.5465
#   Manta 18/50: Fitness (MAE) = 6.4683
#   Manta 19/50: Fitness (MAE) = 12.0024
#   Manta 20/50: Fitness (MAE) = 18.7762
#   Manta 21/50: Fitness (MAE) = 6.5860
#   Manta 22/50: Fitness (MAE) = 14.0445
#   Manta 23/50: Fitness (MAE) = 26.5523
#   Manta 24/50: Fitness (MAE) = 11.1454
#   Manta 25/50: Fitness (MAE) = 7.8089
#   Manta 26/50: Fitness (MAE) = 11.6636
#   Manta 27/50: Fitness (MAE) = 15.2286
#   Manta 28/50: Fitness (MAE) = 28.8511
#   Manta 29/50: Fitness (MAE) = 29.9698
#   Manta 30/50: Fitness (MAE) = 9.9768
#   Manta 31/50: Fitness (MAE) = 7.7710
#   Manta 32/50: Fitness (MAE) = 32.2623
#   Manta 33/50: Fitness (MAE) = 6.8201
#   Manta 34/50: Fitness (MAE) = 11.0718
#   Manta 35/50: Fitness (MAE) = 16.5582
#   Manta 36/50: Fitness (MAE) = 26.9297
#   Manta 37/50: Fitness (MAE) = 6.8980
#   Manta 38/50: Fitness (MAE) = 31.8927
#   Manta 39/50: Fitness (MAE) = 34.2391
#   Manta 40/50: Fitness (MAE) = 12.7043
#   Manta 41/50: Fitness (MAE) = 13.8645
#   Manta 42/50: Fitness (MAE) = 37.1907
#   Manta 43/50: Fitness (MAE) = 17.4841
#   Manta 44/50: Fitness (MAE) = 7.5551
#   Manta 45/50: Fitness (MAE) = 7.4024
#   Manta 46/50: Fitness (MAE) = 14.3636
#   Manta 47/50: Fitness (MAE) = 8.2778
#   Manta 48/50: Fitness (MAE) = 11.6943
#   Manta 49/50: Fitness (MAE) = 18.7404
#   Manta 50/50: Fitness (MAE) = 13.8614
# 🏃 View run MRFO_Iteration_16 at: http://localhost:5001/#/experiments/6/runs/5b0db2de952b424eb974ec8979ba0282
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
#
# Iteration 17/20
#   Manta 1/50: Fitness (MAE) = 7.6305
#   Manta 2/50: Fitness (MAE) = 14.4465
#   Manta 3/50: Fitness (MAE) = 11.8482
#   Manta 4/50: Fitness (MAE) = 10.5364
#   Manta 5/50: Fitness (MAE) = 14.8247
#   Manta 6/50: Fitness (MAE) = 32.0699
#   Manta 7/50: Fitness (MAE) = 12.7863
#   Manta 8/50: Fitness (MAE) = 9.1999
#   Manta 9/50: Fitness (MAE) = 7.4702
#   Manta 10/50: Fitness (MAE) = 13.1903
#   Manta 11/50: Fitness (MAE) = 7.9429
#   Manta 12/50: Fitness (MAE) = 15.1823
#   Manta 13/50: Fitness (MAE) = 16.3138
#   Manta 14/50: Fitness (MAE) = 15.3546
#   Manta 15/50: Fitness (MAE) = 15.3384
#   Manta 16/50: Fitness (MAE) = 5.9589
#   Manta 17/50: Fitness (MAE) = 8.7274
#   Manta 18/50: Fitness (MAE) = 11.9693
#   Manta 19/50: Fitness (MAE) = 7.7474
#   Manta 20/50: Fitness (MAE) = 10.4610
#   Manta 21/50: Fitness (MAE) = 14.3199
#   Manta 22/50: Fitness (MAE) = 21.4858
#   Manta 23/50: Fitness (MAE) = 21.2736
#   Manta 24/50: Fitness (MAE) = 6.6571
#   Manta 25/50: Fitness (MAE) = 12.8080
#   Manta 26/50: Fitness (MAE) = 19.8604
#   Manta 27/50: Fitness (MAE) = 22.4264
#   Manta 28/50: Fitness (MAE) = 30.0634
#   Manta 29/50: Fitness (MAE) = 13.4872
#   Manta 30/50: Fitness (MAE) = 8.0451
#   Manta 31/50: Fitness (MAE) = 14.6719
#   Manta 32/50: Fitness (MAE) = 16.2556
#   Manta 33/50: Fitness (MAE) = 7.6450
#   Manta 34/50: Fitness (MAE) = 5.7226
#   New Best Fitness: 5.7226
#   Manta 35/50: Fitness (MAE) = 10.0225
#   Manta 36/50: Fitness (MAE) = 15.0385
#   Manta 37/50: Fitness (MAE) = 9.4925
#   Manta 38/50: Fitness (MAE) = 19.2101
#   Manta 39/50: Fitness (MAE) = 8.1392
#   Manta 40/50: Fitness (MAE) = 23.7716
#   Manta 41/50: Fitness (MAE) = 14.5942
#   Manta 42/50: Fitness (MAE) = 6.7562
#   Manta 43/50: Fitness (MAE) = 10.9405
#   Manta 44/50: Fitness (MAE) = 8.1992
#   Manta 45/50: Fitness (MAE) = 6.4715
#   Manta 46/50: Fitness (MAE) = 13.2518
#   Manta 47/50: Fitness (MAE) = 17.4158
#   Manta 48/50: Fitness (MAE) = 21.3023
#   Manta 49/50: Fitness (MAE) = 5.9391
#   Manta 50/50: Fitness (MAE) = 15.5755
# 🏃 View run MRFO_Iteration_17 at: http://localhost:5001/#/experiments/6/runs/6ece151003df4721bbca5c3439f7b165
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
#
# Iteration 18/20
#   Manta 1/50: Fitness (MAE) = 32.2623
#   Manta 2/50: Fitness (MAE) = 13.5949
#   Manta 3/50: Fitness (MAE) = 13.6319
#   Manta 4/50: Fitness (MAE) = 15.1872
#   Manta 5/50: Fitness (MAE) = 11.8936
#   Manta 6/50: Fitness (MAE) = 7.6301
#   Manta 7/50: Fitness (MAE) = 20.7686
#   Manta 8/50: Fitness (MAE) = 9.9832
#   Manta 9/50: Fitness (MAE) = 20.2237
#   Manta 10/50: Fitness (MAE) = 11.1578
#   Manta 11/50: Fitness (MAE) = 25.5687
#   Manta 12/50: Fitness (MAE) = 18.8329
#   Manta 13/50: Fitness (MAE) = 10.3056
#   Manta 14/50: Fitness (MAE) = 10.2513
#   Manta 15/50: Fitness (MAE) = 22.2194
#   Manta 16/50: Fitness (MAE) = 15.9130
#   Manta 17/50: Fitness (MAE) = 13.2992
#   Manta 18/50: Fitness (MAE) = 30.7558
#   Manta 19/50: Fitness (MAE) = 23.1597
#   Manta 20/50: Fitness (MAE) = 20.3480
#   Manta 21/50: Fitness (MAE) = 7.8602
#   Manta 22/50: Fitness (MAE) = 15.3231
#   Manta 23/50: Fitness (MAE) = 24.3173
#   Manta 24/50: Fitness (MAE) = 23.8345
#   Manta 25/50: Fitness (MAE) = 16.3861
#   Manta 26/50: Fitness (MAE) = 35.6041
#   Manta 27/50: Fitness (MAE) = 10.7970
#   Manta 28/50: Fitness (MAE) = 34.4268
#   Manta 29/50: Fitness (MAE) = 10.1358
#   Manta 30/50: Fitness (MAE) = 9.7513
#   Manta 31/50: Fitness (MAE) = 18.9122
#   Manta 32/50: Fitness (MAE) = 9.5543
#   Manta 33/50: Fitness (MAE) = 26.4926
#   Manta 34/50: Fitness (MAE) = 10.0947
#   Manta 35/50: Fitness (MAE) = 17.3164
#   Manta 36/50: Fitness (MAE) = 10.2937
#   Manta 37/50: Fitness (MAE) = 42.5490
#   Manta 38/50: Fitness (MAE) = 10.1747
#   Manta 39/50: Fitness (MAE) = 19.2087
#   Manta 40/50: Fitness (MAE) = 31.7690
#   Manta 41/50: Fitness (MAE) = 11.4822
#   Manta 42/50: Fitness (MAE) = 23.1106
#   Manta 43/50: Fitness (MAE) = 13.6827
#   Manta 44/50: Fitness (MAE) = 7.4635
#   Manta 45/50: Fitness (MAE) = 14.7747
#   Manta 46/50: Fitness (MAE) = 41.9008
#   Manta 47/50: Fitness (MAE) = 10.9948
#   Manta 48/50: Fitness (MAE) = 21.1694
#   Manta 49/50: Fitness (MAE) = 9.2004
#   Manta 50/50: Fitness (MAE) = 32.6241
# 🏃 View run MRFO_Iteration_18 at: http://localhost:5001/#/experiments/6/runs/862f841fb7c04d019f467085f1ccee84
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
#
# Iteration 19/20
#   Manta 1/50: Fitness (MAE) = 10.3716
#   Manta 2/50: Fitness (MAE) = 6.6278
#   Manta 3/50: Fitness (MAE) = 21.6704
#   Manta 4/50: Fitness (MAE) = 36.4079
#   Manta 5/50: Fitness (MAE) = 9.3427
#   Manta 6/50: Fitness (MAE) = 15.2169
#   Manta 7/50: Fitness (MAE) = 31.8856
#   Manta 8/50: Fitness (MAE) = 17.3730
#   Manta 9/50: Fitness (MAE) = 12.4296
#   Manta 10/50: Fitness (MAE) = 18.4690
#   Manta 11/50: Fitness (MAE) = 32.3383
#   Manta 12/50: Fitness (MAE) = 24.2421
#   Manta 13/50: Fitness (MAE) = 35.0836
#   Manta 14/50: Fitness (MAE) = 29.1502
#   Manta 15/50: Fitness (MAE) = 9.8901
#   Manta 16/50: Fitness (MAE) = 8.4000
#   Manta 17/50: Fitness (MAE) = 11.1365
#   Manta 18/50: Fitness (MAE) = 14.8636
#   Manta 19/50: Fitness (MAE) = 25.3736
#   Manta 20/50: Fitness (MAE) = 7.6855
#   Manta 21/50: Fitness (MAE) = 7.3563
#   Manta 22/50: Fitness (MAE) = 44.0899
#   Manta 23/50: Fitness (MAE) = 16.1002
#   Manta 24/50: Fitness (MAE) = 24.0022
#   Manta 25/50: Fitness (MAE) = 19.9883
#   Manta 26/50: Fitness (MAE) = 18.0170
#   Manta 27/50: Fitness (MAE) = 18.0429
#   Manta 28/50: Fitness (MAE) = 7.6224
#   Manta 29/50: Fitness (MAE) = 41.6032
#   Manta 30/50: Fitness (MAE) = 13.7744
#   Manta 31/50: Fitness (MAE) = 5.8128
#   Manta 32/50: Fitness (MAE) = 35.5606
#   Manta 33/50: Fitness (MAE) = 6.4591
#   Manta 34/50: Fitness (MAE) = 41.7206
#   Manta 35/50: Fitness (MAE) = 20.2744
#   Manta 36/50: Fitness (MAE) = 5.8700
#   Manta 37/50: Fitness (MAE) = 8.4077
#   Manta 38/50: Fitness (MAE) = 20.4891
#   Manta 39/50: Fitness (MAE) = 20.2962
#   Manta 40/50: Fitness (MAE) = 29.8783
#   Manta 41/50: Fitness (MAE) = 14.2986
#   Manta 42/50: Fitness (MAE) = 29.7531
#   Manta 43/50: Fitness (MAE) = 8.4609
#   Manta 44/50: Fitness (MAE) = 11.3293
#   Manta 45/50: Fitness (MAE) = 17.0281
#   Manta 46/50: Fitness (MAE) = 9.8639
#   Manta 47/50: Fitness (MAE) = 14.6469
#   Manta 48/50: Fitness (MAE) = 6.7168
#   Manta 49/50: Fitness (MAE) = 30.5236
#   Manta 50/50: Fitness (MAE) = 19.0210
# 🏃 View run MRFO_Iteration_19 at: http://localhost:5001/#/experiments/6/runs/046d2698ce40422c8177e893d26c9e0b
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
#
# Iteration 20/20
#   Manta 1/50: Fitness (MAE) = 29.0102
#   Manta 2/50: Fitness (MAE) = 16.7507
#   Manta 3/50: Fitness (MAE) = 12.5148
#   Manta 4/50: Fitness (MAE) = 12.0878
#   Manta 5/50: Fitness (MAE) = 7.4579
#   Manta 6/50: Fitness (MAE) = 11.1216
#   Manta 7/50: Fitness (MAE) = 26.3375
#   Manta 8/50: Fitness (MAE) = 20.1230
#   Manta 9/50: Fitness (MAE) = 7.7170
#   Manta 10/50: Fitness (MAE) = 31.2654
#   Manta 11/50: Fitness (MAE) = 9.1386
#   Manta 12/50: Fitness (MAE) = 19.6151
#   Manta 13/50: Fitness (MAE) = 14.8150
#   Manta 14/50: Fitness (MAE) = 8.0911
#   Manta 15/50: Fitness (MAE) = 20.0023
#   Manta 16/50: Fitness (MAE) = 12.0624
#   Manta 17/50: Fitness (MAE) = 7.6275
#   Manta 18/50: Fitness (MAE) = 18.0833
#   Manta 19/50: Fitness (MAE) = 10.9223
#   Manta 20/50: Fitness (MAE) = 27.6192
#   Manta 21/50: Fitness (MAE) = 7.7071
#   Manta 22/50: Fitness (MAE) = 9.6301
#   Manta 23/50: Fitness (MAE) = 32.7526
#   Manta 24/50: Fitness (MAE) = 16.2354
#   Manta 25/50: Fitness (MAE) = 15.7806
#   Manta 26/50: Fitness (MAE) = 36.5669
#   Manta 27/50: Fitness (MAE) = 11.1760
#   Manta 28/50: Fitness (MAE) = 12.6494
#   Manta 29/50: Fitness (MAE) = 32.8944
#   Manta 30/50: Fitness (MAE) = 11.0571
#   Manta 31/50: Fitness (MAE) = 26.6392
#   Manta 32/50: Fitness (MAE) = 32.0341
#   Manta 33/50: Fitness (MAE) = 7.6045
#   Manta 34/50: Fitness (MAE) = 8.0771
#   Manta 35/50: Fitness (MAE) = 6.7519
#   Manta 36/50: Fitness (MAE) = 23.5961
#   Manta 37/50: Fitness (MAE) = 40.4827
#   Manta 38/50: Fitness (MAE) = 36.8057
#   Manta 39/50: Fitness (MAE) = 6.5786
#   Manta 40/50: Fitness (MAE) = 7.7376
#   Manta 41/50: Fitness (MAE) = 7.4261
#   Manta 42/50: Fitness (MAE) = 11.9493
#   Manta 43/50: Fitness (MAE) = 8.8704
#   Manta 44/50: Fitness (MAE) = 15.9135
#   Manta 45/50: Fitness (MAE) = 27.6799
#   Manta 46/50: Fitness (MAE) = 42.9335
#   Manta 47/50: Fitness (MAE) = 8.5052
#   Manta 48/50: Fitness (MAE) = 23.7829
#   Manta 49/50: Fitness (MAE) = 10.2774
#   Manta 50/50: Fitness (MAE) = 19.5010
# 🏃 View run MRFO_Iteration_20 at: http://localhost:5001/#/experiments/6/runs/7ffb0a27099247bdaac1ed1a190125f3
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
#
# Best MRFO Configuration: LR=0.0007943282347242813, Layers=3, Heads=8, FF=512
#   MAE: 22.25664710998535, RMSE: 28.942445666059605, MAPE: 2.7604125440120697%, SMAPE: 2.7419636249542236%
# 2025/05/04 03:48:53 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Best_MRFO_Run at: http://localhost:5001/#/experiments/6/runs/2ac8f7d94ddb4fe08e93863da7ca0b0b
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
