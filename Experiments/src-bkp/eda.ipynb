# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error
import seaborn as sns

import torch
import torch.nn as nn
import torch.optim as optim

metric_df = pd.read_pickle("../data/ts.pkl")
metric_df.head()

ts = metric_df["value"].astype(float).resample("min").mean()
sns.set()
ts.plot(figsize=(15, 10))
plt.title("Visualize time series")
plt.ylabel("Node memory active bytes")
plt.show()
# Out:
#                                                      __name__  \
# timestamp
# 2021-02-02 05:00:04.720999936+00:00  node_memory_Active_bytes
# 2021-02-02 05:00:14.709000192+00:00  node_memory_Active_bytes
# 2021-02-02 05:00:24.709000192+00:00  node_memory_Active_bytes
# 2021-02-02 05:00:34.709000192+00:00  node_memory_Active_bytes
# 2021-02-02 05:00:44.709000192+00:00  node_memory_Active_bytes
#
#                                                           instance   job  \
# timestamp
# 2021-02-02 05:00:04.720999936+00:00  demo.robustperception.io:9100  node
# 2021-02-02 05:00:14.709000192+00:00  demo.robustperception.io:9100  node
# 2021-02-02 05:00:24.709000192+00:00  demo.robustperception.io:9100  node
# 2021-02-02 05:00:34.709000192+00:00  demo.robustperception.io:9100  node
# 2021-02-02 05:00:44.709000192+00:00  demo.robustperception.io:9100  node
#
#                                          value
# timestamp
# 2021-02-02 05:00:04.720999936+00:00  758050816
# 2021-02-02 05:00:14.709000192+00:00  735338496
# 2021-02-02 05:00:24.709000192+00:00  708128768
# 2021-02-02 05:00:34.709000192+00:00  688300032
# 2021-02-02 05:00:44.709000192+00:00  685510656
